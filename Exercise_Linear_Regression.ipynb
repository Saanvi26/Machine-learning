# %% [markdown]
# <a href="https://colab.research.google.com/github/Saanvi26/Machine-learning/blob/main/Exercise_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
df=pd.read_csv("canada_per_capita_income.csv")
# %matplotlib inline
print(df.columns)
plt.scatter(df['year'], df['per capita income (US$)'], color="red", marker="+")
plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.title("Per Capita Income in Canada Over Years")
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')
# Text(0.5, 1.0, 'Per Capita Income in Canada Over Years')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df[['per capita income (US$)']])
reg.predict([[2022]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[42945.62424486]])
